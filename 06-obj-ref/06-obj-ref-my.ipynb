# %%
class Gizmo:
    def __init__(self):
        print(f'Gizmo id: {id(self)}')

# %%
x = Gizmo()
# Out:
# Gizmo id: 139964324471744

# %%
y = Gizmo() * 10
# Out:
# Gizmo id: 139964314373008
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y = Gizmo() * 10
#
# TypeError: unsupported operand type(s) for *: 'Gizmo' and 'int'

# %%
dir()

# %%
a = [10, 20]
b = [a, 30]
a.append(b)

b
# Out:
# [[10, 20, [...]], 30]

# %%
a = [1, 2]
b = a

# %%
del a
b
# Out:
# [1, 2]
